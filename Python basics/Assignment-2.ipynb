# %%
"""
1.What are the two values of the Boolean data type? How do you write them?
# true, flase 
is_cold = True  -This means it is sunny
is_raining = False  - This means it is not raining


2. What are the three different types of Boolean operators?
# and , or, not 

3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
AND 
T,T-T
T,F-F
F,T-F
F,F-F

OR
T,T-T
T,F-T
F,T-T
F,F-F

NOT
T-F
F-T

4. What are the values of the following expressions?

(5 > 4) and (3 == 5) = FALSE 

not (5 > 4) = FALSE

(5 > 4) or (3 == 5) = TRUE

not ((5 > 4) or (3 == 5)) = FALSE

(True and True) and (True == False) = FALSE

(not False) or (not True) = TRUE


5. What are the six comparison operators?

==	Equal to	
!=	Not equal to	
>	Greater than	
<	Less than	
>=	Greater than or equal to	
<=	Less than or equal to

6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
Equal to (==) Operator:
The operator is used for comparison. 
It checks if the values on both sides are equal.
It returns a Boolean value (True or False).
Used to compare two values (check if they are equal).

Assignment (=) Operator:
The operator is used to assign a value to a variable.
It does not return a Boolean value. 
Instead, it stores the value on the right-hand side into the variable on the left-hand side.
Used to assign a value to a variable.


7. Identify the three blocks in this code:

spam = 0

if spam == 10:

print('eggs')

if spam > 5:

print('bacon')

else:

print('ham')

print('spam')

print('spam')


Block 1: The first if statement and its body:
Condition: spam == 10
Body: print('eggs')
Block 2: The second if statement and its associated else block:
Condition: spam > 5
Body (if spam > 5 is true): print('bacon')
Else body (if spam > 5 is false): print('ham')
Block 3: The two standalone print('spam') statements:
print('spam')
print('spam')

8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

spam = 1  

if spam == 1:
    print("Hello")
elif spam == 2:
    print("Howdy")
else:
    print("Greetings!")

 

9.If your programme is stuck in an endless loop, what keys you’ll press?

In jupyter Stop button (a square icon in the toolbar) or Kernel > Interrupt from the menu.

i) Stop button: Click the Stop button (the square icon) in the toolbar. This will interrupt the current execution and stop the loop.
ii) Kernel > Interrupt: From the menu at the top of the Jupyter interface, go to Kernel > Interrupt. This will send an interrupt signal to the kernel, which should stop the running code.


10. How can you tell the difference between break and continue?

break: 
Purpose: It exits the loop entirely, stopping further iterations.
Usage: When the condition for break is met, the loop terminates immediately, and the program continues with the first line of code after the loop.
continue: 
Purpose: It skips the current iteration and moves to the next iteration of the loop.
Usage: When the condition for continue is met, the rest of the current loop iteration is skipped, and the loop moves on to the next iteration.


11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

range(10): Starts from 0 and goes up to 9 (default start is 0, default step is 1).
range(0, 10): Starts from 0 and goes up to 9 (explicitly specifies the start and stop, with default step 1).
range(0, 10, 1): Starts from 0, goes up to 9, and steps by 1 (explicit start, stop, and step).


12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

# Using for loop
for i in range(1, 11):
    print(i)

# Using while loop
i = 1
while i <= 10:
    print(i)
    i += 1



13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?
import spam
spam.bacon()
